# %% [markdown]
# <!-- ---
# title: "Week 6"
# title-block-banner: true
# title-block-style: default
# execute:
#   freeze: true
#   cache: true
# format: html
# # format: pdf
# --- -->

# %%
# renv::activate(dir)

# %% [markdown]
# #### Packages we will require this week

# %%
packages <- c(
    # Old packages
    "ISLR2",
    "dplyr",
    "tidyr",
    "readr",
    "purrr",
    "repr",
    "tidyverse",
    "kableExtra",
    "IRdisplay",
    "car",
    "corrplot",
    # NEW
    "torch",
    "torchvision",
    "luz",
    # Dimension reduction
    "dimRed",
    "RSpectra"
)

# renv::install(packages)
sapply(packages, require, character.only=TRUE)
# Out:
# Loading required package: dimRed
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# "there is no package called 'dimRed'"
# Loading required package: RSpectra
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# "there is no package called 'RSpectra'"
#       ISLR2       dplyr       tidyr       readr       purrr        repr
#        TRUE        TRUE        TRUE        TRUE        TRUE        TRUE
#   tidyverse  kableExtra   IRdisplay         car    corrplot       torch
#        TRUE        TRUE        TRUE        TRUE        TRUE        TRUE
# torchvision         luz      dimRed    RSpectra
#        TRUE        TRUE       FALSE       FALSE

# %% [markdown]
# ---
#
#
# ### Agenda:
#
# 1. Real-world neural network classification
# 1. Dataloaders
# 1. Torch for image classification

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ## Titanic

# %%
url <- "https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"

df <- read_csv(url) %>%
    mutate_if(\(x) is.character(x), as.factor) %>%
    mutate(y = Survived) %>%
    select(-c(Name, Survived)) %>%
    (\(x) {
        names(x) <- tolower(names(x))
        x
    })

df %>% head
# Out:
# Rows: 887 Columns: 8
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (2): Name, Sex
# dbl (6): Survived, Pclass, Age, Siblings/Spouses Aboard, Parents/Children Ab...
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   pclass sex    age siblings/spouses aboard parents/children aboard fare    y
# 1 3      male   22  1                       0                        7.2500 0
# 2 1      female 38  1                       0                       71.2833 1
# 3 3      female 26  0                       0                        7.9250 1
# 4 1      female 35  1                       0                       53.1000 1
# 5 3      male   35  0                       0                        8.0500 0
# 6 3      male   27  0                       0                        8.4583 0

# %% [markdown]
# ## Breast Cancer Prediction

# %%
# url <- "https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data"

# col_names <- c("id", "diagnosis", paste0("feat", 1:30))

# df <- read_csv(
#         url, col_names, col_types = cols()
#     ) %>% 
#     select(-id) %>% 
#     mutate(y = ifelse(diagnosis == "M", 1, 0)) %>%
#     select(-diagnosis)


# df %>% head

# %% [markdown]
# ### Train/Test Split

# %%
k <- 5
test_ind <- sample( 1 : nrow(df), floor(nrow(df)/ k ), replace = FALSE)
test_ind
# Out:
#   [1] 544 546 826  74 126 684 500 477  42 452 367 332 220 724 377 791 108 880
#  [19] 667 226 789 486 195  26  12 817 174 347 734 552 262 623 801 480 167 511
#  [37] 670 261 305 413 497 819 857 147  57 682 815 602 209 507  76 642 598 763
#  [55]  98 411 833 580 680 314 165 144 755 514 549 844 810 269 400 748 761 228
#  [73] 640 189 676 420 561 641  92 324 504 488 170 352 884 290 597 707  20 788
#  [91] 825 498 560 109  78 202 366 135 592 100 762 370 820  97  18 140 529 484
# [109] 524 295 364 142  17  45 232 369 320 830 773 253 415 264 436  75 255 757
# [127]  88  55 467 259 190 777  41 103 476 475 194 586 539 710 116 219 478 637
# [145] 660 847 771 258 538 865 492 885 828 509 235   9 376 473 434 327 205 218
# [163] 345 879 396 603 152 558  33 270 214 493 463 227 759 401 153

# %%
df_train <- df[-test_ind, ]
df_test <- df[test_ind, ]

nrow(df_train) + nrow(df_test)
# Out:
# [1] 887

# %% [markdown]
# ### Benchmark with Logistic Regression

# %%
fit_glm <- glm( y ~ . , df_train %>% mutate_at("y", factor), family = binomial())
glm_test <- predict(fit_glm, df_test, output = "reponse")

glm_preds <- ifelse(glm_test > 0.5, 1, 0)
table(glm_preds, df_test$y)
# Out:
#
# glm_preds  0  1
#         0 99 34
#         1  6 38

# %% [markdown]
# ### Neural Net Model

# %%
nn_model <- nn_module(
    initialize = function(p, q1, q2, q3){
        self$hidden1 <- nn_linear(p, q1)
        self$hidden2 <- nn_linear(q1, q2)
        self$hidden3 <- nn_linear(q2, q3)
        self$output <- nn_linear(q3, 1)
        self$activation <- nn_relu()
        self$sigmoid <- nn_sigmoid()
    },
    forward = function(x){
        x %>% 
        self$hidden1() %>% self$activation() %>%
        self$hidden2() %>% self$activation() %>%
        self$hidden3() %>% self$activation() %>%
        self$output() %>% self$sigmoid()
    }
)

# %% [markdown]
# ### Fit using Luz

# %%
M <- model.matrix(y ~ 0 + . , data = df_train)
M
# Out:
#     pclass sexfemale sexmale age `siblings/spouses aboard`
# 1   3      0         1       22  1
# 2   1      1         0       38  1
# 3   3      1         0       26  0
# 4   1      1         0       35  1
# 5   3      0         1       35  0
# 6   3      0         1       27  0
# 7   1      0         1       54  0
# 8   3      0         1        2  3
# 9   2      1         0       14  1
# 10  3      1         0        4  1
# 11  3      0         1       20  0
# 12  3      0         1       39  1
# 13  3      1         0       14  0
# 14  2      1         0       55  0
# 15  3      1         0       31  1
# 16  2      0         1       35  0
# 17  2      0         1       34  0
# 18  3      1         0       15  0
# 19  1      0         1       28  0
# 20  3      1         0        8  3
# 21  3      0         1       26  0
# 22  1      0         1       19  3
# 23  3      1         0       24  0
# 24  3      0         1       23  0
# 25  1      0         1       40  0
# 26  1      1         0       48  1
# 27  2      0         1       66  0
# 28  1      0         1       28  1
# 29  1      0         1       42  1
# 30  3      0         1       18  0
# ... ...    ...       ...     ... ...
# 681 3      1         0       18  0
# 682 1      1         0       45  1
# 683 1      0         1       51  0
# 684 3      1         0       24  0
# 685 3      0         1       30  0
# 686 2      0         1       21  1
# 687 1      1         0       48  0
# 688 3      1         0       14  8
# 689 2      0         1       24  0
# 690 2      1         0       42  0
# 691 2      1         0       27  1
# 692 1      0         1       31  0
# 693 3      0         1        4  1
# 694 3      0         1       26  0
# 695 1      1         0       47  1
# 696 1      0         1       33  0
# 697 3      0         1       47  0
# 698 2      1         0       28  1
# 699 3      1         0       15  0
# 700 3      0         1       20  0
# 701 3      0         1       19  0
# 702 3      0         1       23  0
# 703 1      1         0       56  0
# 704 2      1         0       25  0
# 705 3      0         1       33  0
# 706 3      0         1       25  0
# 707 3      1         0       39  0
# 708 2      0         1       27  0
# 709 1      0         1       26  0
# 710 3      0         1       32  0
#     `parents/children aboard` fare
# 1   0                           7.2500
# 2   0                          71.2833
# 3   0                           7.9250
# 4   0                          53.1000
# 5   0                           8.0500
# 6   0                           8.4583
# 7   0                          51.8625
# 8   1                          21.0750
# 9   0                          30.0708
# 10  1                          16.7000
# 11  0                           8.0500
# 12  5                          31.2750
# 13  0                           7.8542
# 14  0                          16.0000
# 15  0                          18.0000
# 16  0                          26.0000
# 17  0                          13.0000
# 18  0                           8.0292
# 19  0                          35.5000
# 20  1                          21.0750
# 21  0                           7.2250
# 22  2                         263.0000
# 23  0                           7.8792
# 24  0                           7.8958
# 25  0                          27.7208
# 26  0                         146.5208
# 27  0                          10.5000
# 28  0                          82.1708
# 29  0                          52.0000
# 30  0                           7.2292
# ... ...                       ...
# 681 1                           9.3500
# 682 1                         164.8667
# 683 0                          26.5500
# 684 3                          19.2583
# 685 0                           7.2292
# 686 0                          11.5000
# 687 0                          25.9292
# 688 2                          69.5500
# 689 0                          13.0000
# 690 0                          13.0000
# 691 0                          13.8583
# 692 0                          50.4958
# 693 1                          11.1333
# 694 0                           7.8958
# 695 1                          52.5542
# 696 0                           5.0000
# 697 0                           9.0000
# 698 0                          24.0000
# 699 0                           7.2250
# 700 0                           9.8458
# 701 0                           7.8958
# 702 0                           7.8958
# 703 1                          83.1583
# 704 1                          26.0000
# 705 0                           7.8958
# 706 0                           7.0500
# 707 5                          29.1250
# 708 0                          13.0000
# 709 0                          30.0000
# 710 0                           7.7500

# %%
fit_nn <- nn_model %>% 
    setup(loss = nn_bce_loss(),
        optimizer = optim_adam, 
        metrics = list(luz_metric_accuracy())) %>%
    set_hparams(p = ncol(M), q1 = 256, q2 = 128, q3 = 64) %>%
    set_opt_hparams(lr = 0.005) %>%
    fit(data = list(
        model.matrix(y ~ 0 + ., data = df_train), df_train %>% select(y) %>% as.matrix
    ),
        valid_data = list(
        model.matrix(y ~ 0 + ., data = df_test), df_test %>% select(y) %>% as.matrix

        ),
        epochs = 50, verbose = TRUE)
# Out:
# Epoch 1/50
# Train metrics: Loss: 0.6777 - Acc: 12.2273
# Valid metrics: Loss: 0.6129 - Acc: 12.5932
# Epoch 2/50
# Train metrics: Loss: 0.6186 - Acc: 12.1818
# Valid metrics: Loss: 0.6267 - Acc: 12.5932
# Epoch 3/50
# Train metrics: Loss: 0.5956 - Acc: 12.1364
# Valid metrics: Loss: 0.593 - Acc: 12.5932
# Epoch 4/50
# Train metrics: Loss: 0.5862 - Acc: 12.2273
# Valid metrics: Loss: 0.5774 - Acc: 12.5932
# Epoch 5/50
# Train metrics: Loss: 0.5674 - Acc: 12.2273
# Valid metrics: Loss: 0.5466 - Acc: 12.5932
# Epoch 6/50
# Train metrics: Loss: 0.5402 - Acc: 12.1364
# Valid metrics: Loss: 0.5258 - Acc: 12.5932
# Epoch 7/50
# Train metrics: Loss: 0.5164 - Acc: 12.1818
# Valid metrics: Loss: 0.5001 - Acc: 12.5932
# Epoch 8/50
# Train metrics: Loss: 0.5182 - Acc: 12.2273
# Valid metrics: Loss: 0.5305 - Acc: 12.5932
# Epoch 9/50
# Train metrics: Loss: 0.5151 - Acc: 12.0455
# Valid metrics: Loss: 0.4877 - Acc: 12.5932
# Epoch 10/50
# Train metrics: Loss: 0.5018 - Acc: 12.0909
# Valid metrics: Loss: 0.5027 - Acc: 12.5932
# Epoch 11/50
# Train metrics: Loss: 0.4955 - Acc: 12.1818
# Valid metrics: Loss: 0.5092 - Acc: 12.5932
# Epoch 12/50
# Train metrics: Loss: 0.4878 - Acc: 12.0455
# Valid metrics: Loss: 0.551 - Acc: 12.5932
# Epoch 13/50
# Train metrics: Loss: 0.4831 - Acc: 12.1818
# Valid metrics: Loss: 0.5325 - Acc: 12.5932
# Epoch 14/50
# Train metrics: Loss: 0.461 - Acc: 12.1364
# Valid metrics: Loss: 0.5086 - Acc: 12.5932
# Epoch 15/50
# Train metrics: Loss: 0.4543 - Acc: 12.0909
# Valid metrics: Loss: 0.4848 - Acc: 12.5932
# Epoch 16/50
# Train metrics: Loss: 0.4645 - Acc: 12.1818
# Valid metrics: Loss: 0.5105 - Acc: 12.5932
# Epoch 17/50
# Train metrics: Loss: 0.4445 - Acc: 12.1818
# Valid metrics: Loss: 0.4798 - Acc: 12.5932
# Epoch 18/50
# Train metrics: Loss: 0.4571 - Acc: 12.1364
# Valid metrics: Loss: 0.4526 - Acc: 12.5932
# Epoch 19/50
# Train metrics: Loss: 0.4539 - Acc: 12.1818
# Valid metrics: Loss: 0.531 - Acc: 12.5932
# Epoch 20/50
# Train metrics: Loss: 0.431 - Acc: 12.2273
# Valid metrics: Loss: 0.4949 - Acc: 12.5932
# Epoch 21/50
# Train metrics: Loss: 0.4417 - Acc: 12.1818
# Valid metrics: Loss: 0.4757 - Acc: 12.5932
# Epoch 22/50
# Train metrics: Loss: 0.4451 - Acc: 12.1364
# Valid metrics: Loss: 0.4712 - Acc: 12.5932
# Epoch 23/50
# Train metrics: Loss: 0.4125 - Acc: 12.1364
# Valid metrics: Loss: 0.4939 - Acc: 12.5932
# Epoch 24/50
# Train metrics: Loss: 0.4175 - Acc: 12.1364
# Valid metrics: Loss: 0.4674 - Acc: 12.5932
# Epoch 25/50
# Train metrics: Loss: 0.4075 - Acc: 12.2273
# Valid metrics: Loss: 0.5063 - Acc: 12.5932
# Epoch 26/50
# Train metrics: Loss: 0.4114 - Acc: 12.1364
# Valid metrics: Loss: 0.4854 - Acc: 12.5932
# Epoch 27/50
# Train metrics: Loss: 0.4086 - Acc: 12.1364
# Valid metrics: Loss: 0.5217 - Acc: 12.5932
# Epoch 28/50
# Train metrics: Loss: 0.4297 - Acc: 12.1818
# Valid metrics: Loss: 0.4897 - Acc: 12.5932
# Epoch 29/50
# Train metrics: Loss: 0.4091 - Acc: 12.1364
# Valid metrics: Loss: 0.5299 - Acc: 12.5932
# Epoch 30/50
# Train metrics: Loss: 0.4294 - Acc: 12.2273
# Valid metrics: Loss: 0.5114 - Acc: 12.5932
# Epoch 31/50
# Train metrics: Loss: 0.4272 - Acc: 12.1364
# Valid metrics: Loss: 0.4825 - Acc: 12.5932
# Epoch 32/50
# Train metrics: Loss: 0.42 - Acc: 12.2273
# Valid metrics: Loss: 0.4877 - Acc: 12.5932
# Epoch 33/50
# Train metrics: Loss: 0.4134 - Acc: 12.1818
# Valid metrics: Loss: 0.4878 - Acc: 12.5932
# Epoch 34/50
# Train metrics: Loss: 0.4009 - Acc: 12.1818
# Valid metrics: Loss: 0.4894 - Acc: 12.5932
# Epoch 35/50
# Train metrics: Loss: 0.4083 - Acc: 12.0909
# Valid metrics: Loss: 0.4956 - Acc: 12.5932
# Epoch 36/50
# Train metrics: Loss: 0.3948 - Acc: 12.1364
# Valid metrics: Loss: 0.4754 - Acc: 12.5932
# Epoch 37/50
# Train metrics: Loss: 0.3833 - Acc: 12.2727
# Valid metrics: Loss: 0.5393 - Acc: 12.5932
# Epoch 38/50
# Train metrics: Loss: 0.4085 - Acc: 12.2273
# Valid metrics: Loss: 0.4659 - Acc: 12.5932
# Epoch 39/50
# Train metrics: Loss: 0.3894 - Acc: 12.2273
# Valid metrics: Loss: 0.4858 - Acc: 12.5932
# Epoch 40/50
# Train metrics: Loss: 0.4048 - Acc: 12.1364
# Valid metrics: Loss: 0.4754 - Acc: 12.5932
# Epoch 41/50
# Train metrics: Loss: 0.4051 - Acc: 12.1818
# Valid metrics: Loss: 0.497 - Acc: 12.5932
# Epoch 42/50
# Train metrics: Loss: 0.402 - Acc: 12.2273
# Valid metrics: Loss: 0.4734 - Acc: 12.5932
# Epoch 43/50
# Train metrics: Loss: 0.3891 - Acc: 12.1818
# Valid metrics: Loss: 0.5571 - Acc: 12.5932
# Epoch 44/50
# Train metrics: Loss: 0.4134 - Acc: 12.2273
# Valid metrics: Loss: 0.4753 - Acc: 12.5932
# Epoch 45/50
# Train metrics: Loss: 0.3848 - Acc: 12.1364
# Valid metrics: Loss: 0.4933 - Acc: 12.5932
# Epoch 46/50
# Train metrics: Loss: 0.3811 - Acc: 12.1818
# Valid metrics: Loss: 0.5026 - Acc: 12.5932
# Epoch 47/50
# Train metrics: Loss: 0.3743 - Acc: 12.2273
# Valid metrics: Loss: 0.4945 - Acc: 12.5932
# Epoch 48/50
# Train metrics: Loss: 0.3935 - Acc: 12.2273
# Valid metrics: Loss: 0.4993 - Acc: 12.5932
# Epoch 49/50
# Train metrics: Loss: 0.3872 - Acc: 12.0455
# Valid metrics: Loss: 0.493 - Acc: 12.5932
# Epoch 50/50
# Train metrics: Loss: 0.3971 - Acc: 12.2273
# Valid metrics: Loss: 0.4601 - Acc: 12.5932

# %% [markdown]
# Luz expects the data to be input as a list. This is important for the fit part of the code above. In this
# list we need to specify our X and Y. We select every variable but the response in one list and then just
# the response variable in an other. Donʼt forget to use as.matrix() .
#
#
# Also its very useful because it doesnʼt matter what the data set looks like as long as the response
# variable is labeled y the code will work. Shown by the switch of the df from the breast cancer data set
# to the titanic data set.
#
#
# We can now make predictions on this model using the predict function.
# If a model has 0 intercept then when the intercept is 0 then everything else is also 0. This can be useful
# at times. For example if modeling horsepower to car price then it makes sense that if the horsepower is
# 0 then so should the price.
#
#
# In this case the neural net did worse than logistic regression but the good part is that we can change
# some parameters like the learning rate that will give us better results. Also these were small data sets
# but if we were to do this with bigger ones then the neural nets would outperform the logistic regression
# models in a more noticable way
